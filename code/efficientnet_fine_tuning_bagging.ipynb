# %% [markdown]
# ## Prelimiary Operations

# %% [markdown]
# ### Manage the directories

# %%
# Not important
import os
os.listdir("../input/an2dlhw1bal-dataset/splitted_dataset")
# Out:
# ['val', 'test', 'train']

# %%
# To delete a folder
import shutil
if os.path.exists("/kaggle/working/andrea"):
    shutil.rmtree("/kaggle/working/andrea")

# %%
# to remove a file
import os
if os.path.exists("/kaggle/working/model.png"):
    os.remove("/kaggle/working/model.png")

# %%
# to create a folder
import os
directory = "EfficientNet"
parent_dir = "/kaggle/working"
path = os.path.join(parent_dir, directory)
if not os.path.exists(path):
    os.mkdir(path)

# %% [markdown]
# ### Operations

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from PIL import Image

tfk = tf.keras
tfkl = tf.keras.layers
# Out:
# 2022-11-22 12:30:05.609374: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
import warnings
import logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)

tf.get_logger().setLevel(logging.ERROR)
tf.get_logger().setLevel('ERROR')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# ## Importing data

# %%
img_height = 96
img_width =96
batch_size = 32

# %%
# Dataset folders. It is a single folder since we don't need a validation set (OOB validation)
dataset_dir = '../input/balanced-dataset-no-split/dataset'

# %%
# Create the dataset
dataset = tfk.preprocessing.image_dataset_from_directory(dataset_dir, label_mode='categorical', image_size=(img_height, img_width))
# Out:
# Found 4296 files belonging to 8 classes.
# 2022-11-22 12:30:11.348259: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-22 12:30:11.351917: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-11-22 12:30:11.417475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:11.418173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-11-22 12:30:11.418244: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-11-22 12:30:11.455514: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-11-22 12:30:11.455618: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-11-22 12:30:11.477921: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-22 12:30:11.485574: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-22 12:30:11.515895: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-22 12:30:11.525414: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-11-22 12:30:11.529597: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-11-22 12:30:11.529780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:11.530674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:11.532417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-11-22 12:30:11.535166: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-22 12:30:11.536388: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-22 12:30:11.536559: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:11.537166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-11-22 12:30:11.537213: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-11-22 12:30:11.537250: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-11-22 12:30:11.537268: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-11-22 12:30:11.537286: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-22 12:30:11.537303: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-22 12:30:11.537321: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-22 12:30:11.537339: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-11-22 12:30:11.537357: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-11-22 12:30:11.537441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:11.538131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:11.538707: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-11-22 12:30:11.539989: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-11-22 12:30:13.192270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-11-22 12:30:13.192319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-11-22 12:30:13.192330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-11-22 12:30:13.194699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:13.195588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:13.196272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 12:30:13.196837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)

# %%
# Create the X and y tensors from the dataset
X = None
y = None
for images, labels in dataset.as_numpy_iterator():
    # Create the tensor of the images in the batch
    t_img = tf.constant(images)
    if X is not None:   # if this is not the first batch
        # Concatenate the images and labels to the previous one
        X = tf.concat([X,t_img], axis=0)
        y = np.concatenate((y,labels), axis=0)
    else:   # if it is the first batch, simply copy the data into X and y
        X = t_img
        y = labels
print(X.shape)
print(y.shape)
# Out:
# 2022-11-22 12:30:13.674974: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-11-22 12:30:13.678927: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000175000 Hz
# (4296, 96, 96, 3)
# (4296, 8)

# %%
# !cd /kaggle/working/EfficientNet

# %%
# Generator to perform data augmentation

def create_im_data_gen(X_train, y_train, X_test, y_test):
    from tensorflow.keras.preprocessing.image import ImageDataGenerator

    # Create an instance of ImageDataGenerator, and for the trainign with Data Augmentation

    train_data_gen = ImageDataGenerator(rotation_range=20,
                                            height_shift_range=0.2,
                                            width_shift_range=0.2,
                                            zoom_range=0.2,
                                            horizontal_flip=True,
                                            shear_range=0.2,
                                            fill_mode='reflect',
                                            rescale=1/255.)

    valid_data_gen = ImageDataGenerator(rescale=1/255.)

    train_gen = train_data_gen.flow(X_train,
                                    y=y_train,
                                    batch_size=32,
                                    shuffle=True,
                                    seed=seed)

    valid_gen = valid_data_gen.flow(X_test,
                                    y=y_test,
                                    batch_size=32,
                                    shuffle=False,
                                    seed=seed)
    return train_gen, valid_gen

# %%
# Download and plot the EfficientNet model
eff_net = tfk.applications.efficientnet.EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(96,96,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step

# %%
from tensorflow.python.framework.tensor_util import GetNumpyAppendFn

def build_model(input_shape, supernet, l1=None, l2=None, learning_rate=1e-4, model_name="efficient_net"):

    # Use the supernet as feature extractor
    supernet.trainable = True
    # in this way we keep the weights of the CNN part and we will train only the weights of the classifier

    input_layer = tfkl.Input(shape=input_shape, name='input_layer')
    x = supernet(input_layer)
    x = tfkl.GlobalAveragePooling2D()(x)
    x = tfkl.Dropout(0.3, seed=seed)(x)
    outputs = tfkl.Dense(
        8, 
        activation='softmax',
        kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)


    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=outputs, name=model_name)
    
    model.get_layer('efficientnetb0').trainable = True
    
    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.RMSprop(learning_rate), metrics='accuracy')
    
    
    return model

# %%
# Main function that train and evaluate a single model, given the bootstrapped dataset

def evaluate_model(X_train, y_train, X_test, y_test, model_name="efficient_net"):
    train_gen, valid_gen = create_im_data_gen(X_train, y_train, X_test, y_test)
    
    input_shape = (96, 96, 3)
    epochs = 300
    l1=1e-7
    l2=1e-4
    learning_rate = 1e-4
    patience = 20
    
    model = build_model(input_shape, eff_net, l1=l1, l2=l2, learning_rate=learning_rate, model_name=model_name)
    
    # Train the model
    model_history = model.fit(
        x = train_gen,
        batch_size = 256,
        epochs = epochs,
        validation_data = valid_gen,
        callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=patience, restore_best_weights=True)],
    ).history
    
    # Predict the test set with the CNN
    predictions = model.predict(X_test)

    # Compute the confusion matrix
    cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

    # Compute the classification metrics
    accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
    precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
    recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
    f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
    print('Accuracy:',accuracy.round(4))
    print('Precision:',precision.round(4))
    print('Recall:',recall.round(4))
    print('F1:',f1.round(4))
    score = {'confusion_matrix': cm, 'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}
    
    return model, score

# %%
from sklearn.utils import resample

# multiple train-test splits
n_splits = 10
scores = list()
n_samples = len(X)
for i in range(n_splits):
    # select indexes
    ix = [i for i in range(n_samples)]
    train_ix = resample(ix, replace=True, n_samples=n_samples)
    test_ix = [x for x in ix if x not in train_ix]
    # select data
    X_train, y_train = tf.gather(X, indices=train_ix), y[train_ix]
    X_test, y_test = tf.gather(X, indices=test_ix), y[test_ix]
    # evaluate model
    model_name = "efficient_net" + str(i)
    model, score = evaluate_model(X_train, y_train, X_test, y_test, model_name=model_name)
    
    # Save all the models in different directories, to be used after for prediction
    directory = "EfficientNet" + str(i)
    parent_dir = "/kaggle/working/EfficientNet"
    path = os.path.join(parent_dir, directory)
    if os.path.exists(path):
        shutil.rmtree(path)
    os.mkdir(path)
    model.save(path)
    del model
    
    scores.append(score)
# Out:
# Epoch 1/300
# 2022-11-22 12:30:47.859601: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022
300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0514 - accuracy: 0.9855 - val_loss: 3.2351 - val_accuracy: 0.2082
# Epoch 26/300
# 135/135 [==============================] - 16s 120ms/step - loss: 0.0541 - accuracy: 0.9803 - val_loss: 3.7694 - val_accuracy: 0.3180
# Epoch 27/300
# 135/135 [==============================] - 16s 120ms/step - loss: 0.0455 - accuracy: 0.9859 - val_loss: 3.3158 - val_accuracy: 0.4395
# Epoch 28/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0495 - accuracy: 0.9813 - val_loss: 3.2808 - val_accuracy: 0.2369
# Epoch 29/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0560 - accuracy: 0.9817 - val_loss: 3.4718 - val_accuracy: 0.2993
# Epoch 30/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0275 - accuracy: 0.9908 - val_loss: 4.3367 - val_accuracy: 0.2986
# Epoch 31/300
# 135/135 [==============================] - 18s 135ms/step - loss: 0.0413 - accuracy: 0.9866 - val_loss: 2.4001 - val_accuracy: 0.4507
# Epoch 32/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0418 - accuracy: 0.9872 - val_loss: 4.0174 - val_accuracy: 0.3940
# Epoch 33/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0436 - accuracy: 0.9882 - val_loss: 3.3363 - val_accuracy: 0.3111
# Epoch 34/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0308 - accuracy: 0.9895 - val_loss: 3.0301 - val_accuracy: 0.3909
# Epoch 35/300
# 135/135 [==============================] - 18s 135ms/step - loss: 0.0312 - accuracy: 0.9904 - val_loss: 3.4238 - val_accuracy: 0.4776
# Epoch 36/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0255 - accuracy: 0.9897 - val_loss: 2.6047 - val_accuracy: 0.3959
# Epoch 37/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0439 - accuracy: 0.9819 - val_loss: 3.2077 - val_accuracy: 0.2968
# Epoch 38/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0390 - accuracy: 0.9863 - val_loss: 4.6430 - val_accuracy: 0.2219
# Epoch 39/300
# 135/135 [==============================] - 17s 126ms/step - loss: 0.0306 - accuracy: 0.9874 - val_loss: 4.4490 - val_accuracy: 0.3709
# Epoch 40/300
# 135/135 [==============================] - 16s 115ms/step - loss: 0.0347 - accuracy: 0.9878 - val_loss: 5.8404 - val_accuracy: 0.2830
# Epoch 41/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0357 - accuracy: 0.9880 - val_loss: 5.4271 - val_accuracy: 0.2731
# Epoch 42/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0351 - accuracy: 0.9895 - val_loss: 2.6066 - val_accuracy: 0.5480
# Epoch 43/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0510 - accuracy: 0.9845 - val_loss: 3.7091 - val_accuracy: 0.2818
# Epoch 44/300
# 135/135 [==============================] - 18s 131ms/step - loss: 0.0407 - accuracy: 0.9869 - val_loss: 4.0229 - val_accuracy: 0.3903
# Accuracy: 0.1272
# Precision: 0.1306
# Recall: 0.1262
# F1: 0.1155
# Epoch 1/300
# 135/135 [==============================] - 31s 143ms/step - loss: 0.1341 - accuracy: 0.9592 - val_loss: 2.6418 - val_accuracy: 0.3740
# Epoch 2/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0902 - accuracy: 0.9728 - val_loss: 3.1977 - val_accuracy: 0.3352
# Epoch 3/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0849 - accuracy: 0.9740 - val_loss: 2.6220 - val_accuracy: 0.3461
# Epoch 4/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0772 - accuracy: 0.9764 - val_loss: 5.8369 - val_accuracy: 0.2290
# Epoch 5/300
# 135/135 [==============================] - 18s 136ms/step - loss: 0.0674 - accuracy: 0.9768 - val_loss: 2.1230 - val_accuracy: 0.3925
# Epoch 6/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0809 - accuracy: 0.9794 - val_loss: 5.1775 - val_accuracy: 0.3810
# Epoch 7/300
# 135/135 [==============================] - 16s 115ms/step - loss: 0.0564 - accuracy: 0.9798 - val_loss: 7.0090 - val_accuracy: 0.2684
# Epoch 8/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.
300
# 135/135 [==============================] - 16s 116ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 3.1148 - val_accuracy: 0.3270
# Epoch 4/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0566 - accuracy: 0.9792 - val_loss: 3.8172 - val_accuracy: 0.3092
# Epoch 5/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0564 - accuracy: 0.9815 - val_loss: 2.1182 - val_accuracy: 0.3467
# Epoch 6/300
# 135/135 [==============================] - 19s 137ms/step - loss: 0.0449 - accuracy: 0.9861 - val_loss: 1.8710 - val_accuracy: 0.4453
# Epoch 7/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0398 - accuracy: 0.9905 - val_loss: 2.0588 - val_accuracy: 0.5420
# Epoch 8/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0497 - accuracy: 0.9842 - val_loss: 4.5022 - val_accuracy: 0.2621
# Epoch 9/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0366 - accuracy: 0.9876 - val_loss: 4.1000 - val_accuracy: 0.2882
# Epoch 10/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0394 - accuracy: 0.9878 - val_loss: 2.7490 - val_accuracy: 0.2570
# Epoch 11/300
# 135/135 [==============================] - 20s 145ms/step - loss: 0.0551 - accuracy: 0.9809 - val_loss: 2.4029 - val_accuracy: 0.4192
# Epoch 12/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0434 - accuracy: 0.9838 - val_loss: 6.4016 - val_accuracy: 0.2583
# Epoch 13/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0402 - accuracy: 0.9865 - val_loss: 2.9194 - val_accuracy: 0.3384
# Epoch 14/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0433 - accuracy: 0.9836 - val_loss: 3.2146 - val_accuracy: 0.4567
# Epoch 15/300
# 135/135 [==============================] - 19s 143ms/step - loss: 0.0462 - accuracy: 0.9856 - val_loss: 2.7527 - val_accuracy: 0.5439
# Epoch 16/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0459 - accuracy: 0.9843 - val_loss: 3.4384 - val_accuracy: 0.3836
# Epoch 17/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0331 - accuracy: 0.9866 - val_loss: 1.7882 - val_accuracy: 0.5064
# Epoch 18/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0427 - accuracy: 0.9834 - val_loss: 8.1580 - val_accuracy: 0.2545
# Epoch 19/300
# 135/135 [==============================] - 16s 116ms/step - loss: 0.0363 - accuracy: 0.9865 - val_loss: 5.5553 - val_accuracy: 0.2576
# Epoch 20/300
# 135/135 [==============================] - 19s 140ms/step - loss: 0.0396 - accuracy: 0.9847 - val_loss: 1.8734 - val_accuracy: 0.5872
# Epoch 21/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0318 - accuracy: 0.9886 - val_loss: 2.8056 - val_accuracy: 0.4796
# Accuracy: 0.1158
# Precision: 0.1209
# Recall: 0.1155
# F1: 0.1051
# Epoch 1/300
# 135/135 [==============================] - 34s 117ms/step - loss: 0.0839 - accuracy: 0.9753 - val_loss: 2.8958 - val_accuracy: 0.3754
# Epoch 2/300
# 135/135 [==============================] - 16s 115ms/step - loss: 0.0605 - accuracy: 0.9806 - val_loss: 1.2065 - val_accuracy: 0.6646
# Epoch 3/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0578 - accuracy: 0.9817 - val_loss: 3.4757 - val_accuracy: 0.3177
# Epoch 4/300
# 135/135 [==============================] - 20s 147ms/step - loss: 0.0466 - accuracy: 0.9868 - val_loss: 5.1296 - val_accuracy: 0.1921
# Epoch 5/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0445 - accuracy: 0.9861 - val_loss: 2.3533 - val_accuracy: 0.4280
# Epoch 6/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0586 - accuracy: 0.9832 - val_loss: 3.2149 - val_accuracy: 0.2822
# Epoch 7/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0582 - accuracy: 0.9820 - val_loss: 2.8367 - val_accuracy: 0.3697
# Epoch 8/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.
300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0402 - accuracy: 0.9877 - val_loss: 3.2711 - val_accuracy: 0.2631
# Epoch 13/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0443 - accuracy: 0.9858 - val_loss: 5.9580 - val_accuracy: 0.2800
# Epoch 14/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0354 - accuracy: 0.9898 - val_loss: 8.4244 - val_accuracy: 0.1850
# Epoch 15/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0312 - accuracy: 0.9902 - val_loss: 3.1043 - val_accuracy: 0.4594
# Epoch 16/300
# 135/135 [==============================] - 21s 153ms/step - loss: 0.0373 - accuracy: 0.9873 - val_loss: 2.8131 - val_accuracy: 0.3375
# Epoch 17/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0434 - accuracy: 0.9861 - val_loss: 3.8023 - val_accuracy: 0.3400
# Epoch 18/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0356 - accuracy: 0.9881 - val_loss: 11.2399 - val_accuracy: 0.1206
# Epoch 19/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0275 - accuracy: 0.9918 - val_loss: 4.1471 - val_accuracy: 0.2706
# Epoch 20/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0309 - accuracy: 0.9880 - val_loss: 7.4075 - val_accuracy: 0.1731
# Epoch 21/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0394 - accuracy: 0.9878 - val_loss: 2.9641 - val_accuracy: 0.4250
# Accuracy: 0.1306
# Precision: 0.1315
# Recall: 0.1291
# F1: 0.1242
# Epoch 1/300
# 135/135 [==============================] - 38s 169ms/step - loss: 0.0771 - accuracy: 0.9739 - val_loss: 4.6180 - val_accuracy: 0.2623
# Epoch 2/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0597 - accuracy: 0.9817 - val_loss: 1.7480 - val_accuracy: 0.5573
# Epoch 3/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0431 - accuracy: 0.9865 - val_loss: 1.9651 - val_accuracy: 0.5349
# Epoch 4/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0385 - accuracy: 0.9874 - val_loss: 2.2507 - val_accuracy: 0.4440
# Epoch 5/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0481 - accuracy: 0.9831 - val_loss: 2.5128 - val_accuracy: 0.4376
# Epoch 6/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0566 - accuracy: 0.9830 - val_loss: 3.2366 - val_accuracy: 0.2604
# Epoch 7/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0353 - accuracy: 0.9899 - val_loss: 2.2260 - val_accuracy: 0.4786
# Epoch 8/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0399 - accuracy: 0.9851 - val_loss: 3.1465 - val_accuracy: 0.3564
# Epoch 9/300
# 135/135 [==============================] - 19s 139ms/step - loss: 0.0486 - accuracy: 0.9843 - val_loss: 2.5151 - val_accuracy: 0.5099
# Epoch 10/300
# 135/135 [==============================] - 17s 124ms/step - loss: 0.0431 - accuracy: 0.9836 - val_loss: 2.4785 - val_accuracy: 0.4210
# Epoch 11/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0448 - accuracy: 0.9877 - val_loss: 1.5761 - val_accuracy: 0.6206
# Epoch 12/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0498 - accuracy: 0.9851 - val_loss: 3.6887 - val_accuracy: 0.2700
# Epoch 13/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0393 - accuracy: 0.9847 - val_loss: 3.1890 - val_accuracy: 0.3685
# Epoch 14/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0416 - accuracy: 0.9846 - val_loss: 5.5764 - val_accuracy: 0.1945
# Epoch 15/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 6.0267 - val_accuracy: 0.2067
# Epoch 16/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0388 - accuracy: 0.9868 - val_loss: 5.9634 - val_accuracy: 0.2828
# Epoch 17/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0377 - accuracy: 0.9869 - val_loss: 5.0979 - val_accuracy: 0.2860
# Epoch 18/300
# 135/135 [==============================] - 21s 158ms/step - loss: 0.0283 - accuracy: 0.9923 - val_loss: 4.8018 - val_accuracy: 0.1971
# Epoch 19/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0253 - accuracy: 0.9921 - val_loss: 3.0817 - val_accuracy: 0.4440
# Epoch 20/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0294 - accuracy: 0.9890 - val_loss: 3.4727 - val_accuracy: 0.2956
# Epoch 21/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0210 - accuracy: 0.9921 - val_loss: 4.1150 - val_accuracy: 0.3378
# Epoch 22/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0272 - accuracy: 0.9917 - val_loss: 4.6527 - val_accuracy: 0.3186
# Epoch 23/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0299 - accuracy: 0.9901 - val_loss: 2.8626 - val_accuracy: 0.4779
# Epoch 24/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0302 - accuracy: 0.9877 - val_loss: 4.6278 - val_accuracy: 0.3896
# Epoch 25/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0332 - accuracy: 0.9911 - val_loss: 3.8685 - val_accuracy: 0.3877
# Epoch 26/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0374 - accuracy: 0.9880 - val_loss: 3.5898 - val_accuracy: 0.3903
# Epoch 27/300
# 135/135 [==============================] - 21s 158ms/step - loss: 0.0244 - accuracy: 0.9898 - val_loss: 6.1023 - val_accuracy: 0.2079
# Epoch 28/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0196 - accuracy: 0.9931 - val_loss: 3.4920 - val_accuracy: 0.3282
# Epoch 29/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0324 - accuracy: 0.9918 - val_loss: 1.1201 - val_accuracy: 0.7594
# Epoch 30/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 2.1735 - val_accuracy: 0.5829
# Epoch 31/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0215 - accuracy: 0.9922 - val_loss: 8.5389 - val_accuracy: 0.1427
# Epoch 32/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0313 - accuracy: 0.9880 - val_loss: 8.5502 - val_accuracy: 0.2246
# Epoch 33/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0347 - accuracy: 0.9906 - val_loss: 2.6127 - val_accuracy: 0.3788
# Epoch 34/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0350 - accuracy: 0.9890 - val_loss: 3.5436 - val_accuracy: 0.3340
# Epoch 35/300
# 135/135 [==============================] - 16s 119ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 7.3618 - val_accuracy: 0.2502
# Epoch 36/300
# 135/135 [==============================] - 20s 150ms/step - loss: 0.0269 - accuracy: 0.9921 - val_loss: 7.1361 - val_accuracy: 0.2495
# Epoch 37/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0246 - accuracy: 0.9919 - val_loss: 3.4809 - val_accuracy: 0.3948
# Epoch 38/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0413 - accuracy: 0.9881 - val_loss: 3.8054 - val_accuracy: 0.4491
# Epoch 39/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0244 - accuracy: 0.9926 - val_loss: 7.6551 - val_accuracy: 0.2444
# Epoch 40/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0291 - accuracy: 0.9887 - val_loss: 2.2549 - val_accuracy: 0.6136
# Epoch 41/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0299 - accuracy: 0.9907 - val_loss: 2.3665 - val_accuracy: 0.5291
# Epoch 42/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0274 - accuracy: 0.9906 - val_loss: 7.4002 - val_accuracy: 0.2911
# Epoch 43/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0215 - accuracy: 0.9919 - val_loss: 4.6705 - val_accuracy: 0.4306
# Epoch 44/300
# 135/135 [==============================] - 17s 129ms/step - loss: 0.0223 - accuracy: 0.9921 - val_loss: 4.6050 - val_accuracy: 0.3800
# Epoch 45/300
# 135/135 [==============================] - 19s 136ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 5.6859 - val_accuracy: 0.2431
# Epoch 46/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0217 - accuracy: 0.9910 - val_loss: 5.3797 - val_accuracy: 0.1593
# Epoch 47/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0145 - accuracy: 0.9965 - val_loss: 3.0894 - val_accuracy: 0.2898
# Epoch 48/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0252 - accuracy: 0.9908 - val_loss: 4.5490 - val_accuracy: 0.2150
# Epoch 49/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0185 - accuracy: 0.9940 - val_loss: 4.8560 - val_accuracy: 0.1574
# Accuracy: 0.128
# Precision: 0.1217
# Recall: 0.1273
# F1: 0.1164
# Epoch 1/300
# 135/135 [==============================] - 34s 172ms/step - loss: 0.0625 - accuracy: 0.9832 - val_loss: 5.2940 - val_accuracy: 0.2778
# Epoch 2/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0563 - accuracy: 0.9814 - val_loss: 2.7803 - val_accuracy: 0.5329
# Epoch 3/300
# 135/135 [==============================] - 16s 115ms/step - loss: 0.0482 - accuracy: 0.9853 - val_loss: 4.6120 - val_accuracy: 0.3639
# Epoch 4/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0424 - accuracy: 0.9838 - val_loss: 1.6816 - val_accuracy: 0.6095
# Epoch 5/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0404 - accuracy: 0.9879 - val_loss: 2.6329 - val_accuracy: 0.5120
# Epoch 6/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0315 - accuracy: 0.9914 - val_loss: 3.9145 - val_accuracy: 0.3943
# Epoch 7/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0340 - accuracy: 0.9905 - val_loss: 6.4853 - val_accuracy: 0.2601
# Epoch 8/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0417 - accuracy: 0.9888 - val_loss: 1.4843 - val_accuracy: 0.6076
# Epoch 9/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0250 - accuracy: 0.9937 - val_loss: 3.3493 - val_accuracy: 0.3854
# Epoch 10/300
# 135/135 [==============================] - 23s 167ms/step - loss: 0.0280 - accuracy: 0.9922 - val_loss: 2.6553 - val_accuracy: 0.2424
# Epoch 11/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0318 - accuracy: 0.9920 - val_loss: 4.7781 - val_accuracy: 0.1627
# Epoch 12/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0315 - accuracy: 0.9883 - val_loss: 1.5101 - val_accuracy: 0.6652
# Epoch 13/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0310 - accuracy: 0.9893 - val_loss: 3.5651 - val_accuracy: 0.3051
# Epoch 14/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0315 - accuracy: 0.9876 - val_loss: 5.5008 - val_accuracy: 0.2475
# Epoch 15/300
# 135/135 [==============================] - 14s 104ms/step - loss: 0.0229 - accuracy: 0.9937 - val_loss: 1.6807 - val_accuracy: 0.6158
# Epoch 16/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0377 - accuracy: 0.9853 - val_loss: 5.8872 - val_accuracy: 0.2557
# Epoch 17/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 3.1186 - val_accuracy: 0.2810
# Epoch 18/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0304 - accuracy: 0.9903 - val_loss: 8.6469 - val_accuracy: 0.1886
# Epoch 19/300
# 135/135 [==============================] - 23s 168ms/step - loss: 0.0286 - accuracy: 0.9928 - val_loss: 2.8511 - val_accuracy: 0.5405
# Epoch 20/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0221 - accuracy: 0.9906 - val_loss: 2.7232 - val_accuracy: 0.4614
# Epoch 21/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0260 - accuracy: 0.9913 - val_loss: 3.5009 - val_accuracy: 0.3247
# Epoch 22/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 2.5979 - val_accuracy: 0.4747
# Epoch 23/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 4.4295 - val_accuracy: 0.1772
# Epoch 24/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0276 - accuracy: 0.9905 - val_loss: 2.5437 - val_accuracy: 0.4823
# Epoch 25/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0223 - accuracy: 0.9919 - val_loss: 6.5068 - val_accuracy: 0.2089
# Epoch 26/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0324 - accuracy: 0.9900 - val_loss: 6.4555 - val_accuracy: 0.2930
# Epoch 27/300
# 135/135 [==============================] - 14s 105ms/step - loss: 0.0252 - accuracy: 0.9915 - val_loss: 16.8065 - val_accuracy: 0.1247
# Epoch 28/300
# 135/135 [==============================] - 23s 170ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 5.7218 - val_accuracy: 0.2139
# Epoch 29/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0339 - accuracy: 0.9887 - val_loss: 11.4609 - val_accuracy: 0.1854
# Epoch 30/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0272 - accuracy: 0.9933 - val_loss: 3.4745 - val_accuracy: 0.4304
# Epoch 31/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0219 - accuracy: 0.9943 - val_loss: 12.3897 - val_accuracy: 0.1411
# Epoch 32/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0186 - accuracy: 0.9951 - val_loss: 3.1231 - val_accuracy: 0.3557
# Accuracy: 0.1196
# Precision: 0.1166
# Recall: 0.1189
# F1: 0.0952
# Epoch 1/300
# 135/135 [==============================] - 33s 151ms/step - loss: 0.0420 - accuracy: 0.9854 - val_loss: 3.5835 - val_accuracy: 0.3391
# Epoch 2/300
# 135/135 [==============================] - 18s 133ms/step - loss: 0.0361 - accuracy: 0.9892 - val_loss: 2.4785 - val_accuracy: 0.4261
# Epoch 3/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0359 - accuracy: 0.9908 - val_loss: 3.2277 - val_accuracy: 0.3295
# Epoch 4/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0448 - accuracy: 0.9887 - val_loss: 3.0061 - val_accuracy: 0.3986
# Epoch 5/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0373 - accuracy: 0.9872 - val_loss: 3.4856 - val_accuracy: 0.2028
# Epoch 6/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 5.2444 - val_accuracy: 0.2124
# Epoch 7/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0310 - accuracy: 0.9887 - val_loss: 2.4568 - val_accuracy: 0.3116
# Epoch 8/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0345 - accuracy: 0.9898 - val_loss: 2.0946 - val_accuracy: 0.4683
# Epoch 9/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0311 - accuracy: 0.9896 - val_loss: 3.0905 - val_accuracy: 0.3314
# Epoch 10/300
# 135/135 [==============================] - 20s 149ms/step - loss: 0.0279 - accuracy: 0.9900 - val_loss: 5.8512 - val_accuracy: 0.2802
# Epoch 11/300
# 135/135 [==============================] - 18s 130ms/step - loss: 0.0338 - accuracy: 0.9865 - val_loss: 5.2275 - val_accuracy: 0.2898
# Epoch 12/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0311 - accuracy: 0.9910 - val_loss: 2.3544 - val_accuracy: 0.5534
# Epoch 13/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0275 - accuracy: 0.9923 - val_loss: 5.6068 - val_accuracy: 0.3410
# Epoch 14/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0277 - accuracy: 0.9913 - val_loss: 4.6446 - val_accuracy: 0.4050
# Epoch 15/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0302 - accuracy: 0.9904 - val_loss: 11.0957 - val_accuracy: 0.1734
# Epoch 16/300
# 135/135 [==============================] - 16s 115ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 5.0937 - val_accuracy: 0.3487
# Epoch 17/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0210 - accuracy: 0.9908 - val_loss: 9.4544 - val_accuracy: 0.1977
# Epoch 18/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0403 - accuracy: 0.9876 - val_loss: 1.9820 - val_accuracy: 0.4639
# Epoch 19/300
# 135/135 [==============================] - 20s 147ms/step - loss: 0.0249 - accuracy: 0.9915 - val_loss: 2.4207 - val_accuracy: 0.6123
# Epoch 20/300
# 135/135 [==============================] - 18s 133ms/step - loss: 0.0171 - accuracy: 0.9928 - val_loss: 6.4123 - val_accuracy: 0.3071
# Epoch 21/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0200 - accuracy: 0.9913 - val_loss: 11.8213 - val_accuracy: 0.1465
# Epoch 22/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0287 - accuracy: 0.9896 - val_loss: 3.7948 - val_accuracy: 0.3090
# Epoch 23/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0260 - accuracy: 0.9931 - val_loss: 3.3891 - val_accuracy: 0.3583
# Epoch 24/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0355 - accuracy: 0.9925 - val_loss: 1.8369 - val_accuracy: 0.6436
# Epoch 25/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0278 - accuracy: 0.9901 - val_loss: 1.9916 - val_accuracy: 0.6628
# Epoch 26/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0268 - accuracy: 0.9907 - val_loss: 4.0086 - val_accuracy: 0.3065
# Epoch 27/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0163 - accuracy: 0.9949 - val_loss: 2.9742 - val_accuracy: 0.5016
# Epoch 28/300
# 135/135 [==============================] - 21s 154ms/step - loss: 0.0278 - accuracy: 0.9914 - val_loss: 3.6643 - val_accuracy: 0.3538
# Epoch 29/300
# 135/135 [==============================] - 17s 128ms/step - loss: 0.0179 - accuracy: 0.9955 - val_loss: 9.7357 - val_accuracy: 0.2214
# Epoch 30/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0204 - accuracy: 0.9929 - val_loss: 4.0366 - val_accuracy: 0.3608
# Epoch 31/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0276 - accuracy: 0.9924 - val_loss: 4.3707 - val_accuracy: 0.2073
# Epoch 32/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0173 - accuracy: 0.9957 - val_loss: 4.3697 - val_accuracy: 0.2508
# Epoch 33/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0223 - accuracy: 0.9932 - val_loss: 5.2079 - val_accuracy: 0.4530
# Epoch 34/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0234 - accuracy: 0.9903 - val_loss: 6.6752 - val_accuracy: 0.3423
# Epoch 35/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0267 - accuracy: 0.9916 - val_loss: 0.7682 - val_accuracy: 0.7863
# Epoch 36/300
# 135/135 [==============================] - 15s 114ms/step - loss: 0.0267 - accuracy: 0.9916 - val_loss: 4.8117 - val_accuracy: 0.3378
# Epoch 37/300
# 135/135 [==============================] - 20s 146ms/step - loss: 0.0270 - accuracy: 0.9924 - val_loss: 4.7133 - val_accuracy: 0.3692
# Epoch 38/300
# 135/135 [==============================] - 19s 138ms/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 1.5737 - val_accuracy: 0.6852
# Epoch 39/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0194 - accuracy: 0.9956 - val_loss: 2.5209 - val_accuracy: 0.5509
# Epoch 40/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0217 - accuracy: 0.9948 - val_loss: 4.2577 - val_accuracy: 0.4402
# Epoch 41/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0209 - accuracy: 0.9949 - val_loss: 8.5074 - val_accuracy: 0.2866
# Epoch 42/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 5.4005 - val_accuracy: 0.3276
# Epoch 43/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0139 - accuracy: 0.9971 - val_loss: 5.0085 - val_accuracy: 0.3788
# Epoch 44/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0219 - accuracy: 0.9935 - val_loss: 5.4034 - val_accuracy: 0.2514
# Epoch 45/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 2.5046 - val_accuracy: 0.5816
# Epoch 46/300
# 135/135 [==============================] - 20s 149ms/step - loss: 0.0239 - accuracy: 0.9928 - val_loss: 6.2489 - val_accuracy: 0.2137
# Epoch 47/300
# 135/135 [==============================] - 19s 141ms/step - loss: 0.0311 - accuracy: 0.9925 - val_loss: 2.8658 - val_accuracy: 0.5080
# Epoch 48/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0291 - accuracy: 0.9930 - val_loss: 4.6322 - val_accuracy: 0.2220
# Epoch 49/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0207 - accuracy: 0.9910 - val_loss: 9.4661 - val_accuracy: 0.2418
# Epoch 50/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0130 - accuracy: 0.9950 - val_loss: 6.2514 - val_accuracy: 0.3762
# Epoch 51/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0264 - accuracy: 0.9940 - val_loss: 4.7763 - val_accuracy: 0.3455
# Epoch 52/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 9.7405 - val_accuracy: 0.2598
# Epoch 53/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 6.2326 - val_accuracy: 0.2809
# Epoch 54/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0159 - accuracy: 0.9963 - val_loss: 6.3766 - val_accuracy: 0.1945
# Epoch 55/300
# 135/135 [==============================] - 18s 131ms/step - loss: 0.0275 - accuracy: 0.9938 - val_loss: 3.2040 - val_accuracy: 0.4203
# Accuracy: 0.1024
# Precision: 0.1153
# Recall: 0.1024
# F1: 0.0895
# Epoch 1/300
# 135/135 [==============================] - 30s 131ms/step - loss: 0.0396 - accuracy: 0.9885 - val_loss: 3.4355 - val_accuracy: 0.3199
# Epoch 2/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0260 - accuracy: 0.9921 - val_loss: 4.4537 - val_accuracy: 0.2848
# Epoch 3/300
# 135/135 [==============================] - 16s 115ms/step - loss: 0.0383 - accuracy: 0.9874 - val_loss: 2.1195 - val_accuracy: 0.5837
# Epoch 4/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0287 - accuracy: 0.9891 - val_loss: 2.3614 - val_accuracy: 0.5013
# Epoch 5/300
# 135/135 [==============================] - 16s 116ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 2.6882 - val_accuracy: 0.5511
# Epoch 6/300
# 135/135 [==============================] - 23s 168ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 6.4489 - val_accuracy: 0.2618
# Epoch 7/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0273 - accuracy: 0.9890 - val_loss: 3.0418 - val_accuracy: 0.4847
# Epoch 8/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 3.5966 - val_accuracy: 0.2305
# Epoch 9/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0233 - accuracy: 0.9923 - val_loss: 5.4285 - val_accuracy: 0.3276
# Epoch 10/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0327 - accuracy: 0.9908 - val_loss: 3.2268 - val_accuracy: 0.3780
# Epoch 11/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0267 - accuracy: 0.9915 - val_loss: 4.3314 - val_accuracy: 0.3799
# Epoch 12/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0279 - accuracy: 0.9898 - val_loss: 1.2621 - val_accuracy: 0.7209
# Epoch 13/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0188 - accuracy: 0.9922 - val_loss: 6.6976 - val_accuracy: 0.2950
# Epoch 14/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 4.3710 - val_accuracy: 0.3135
# Epoch 15/300
# 135/135 [==============================] - 23s 169ms/step - loss: 0.0277 - accuracy: 0.9926 - val_loss: 9.2629 - val_accuracy: 0.1616
# Epoch 16/300
# 135/135 [==============================] - 16s 120ms/step - loss: 0.0221 - accuracy: 0.9932 - val_loss: 10.2246 - val_accuracy: 0.2797
# Epoch 17/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0237 - accuracy: 0.9939 - val_loss: 3.9800 - val_accuracy: 0.4527
# Epoch 18/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0248 - accuracy: 0.9924 - val_loss: 7.2392 - val_accuracy: 0.1686
# Epoch 19/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0330 - accuracy: 0.9921 - val_loss: 6.0613 - val_accuracy: 0.3231
# Epoch 20/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 7.1432 - val_accuracy: 0.2312
# Epoch 21/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 9.8121 - val_accuracy: 0.1533
# Epoch 22/300
# 135/135 [==============================] - 14s 105ms/step - loss: 0.0219 - accuracy: 0.9936 - val_loss: 3.4357 - val_accuracy: 0.4936
# Epoch 23/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0165 - accuracy: 0.9923 - val_loss: 1.9846 - val_accuracy: 0.6015
# Epoch 24/300
# 135/135 [==============================] - 21s 154ms/step - loss: 0.0137 - accuracy: 0.9945 - val_loss: 11.2142 - val_accuracy: 0.1903
# Epoch 25/300
# 135/135 [==============================] - 19s 137ms/step - loss: 0.0167 - accuracy: 0.9944 - val_loss: 1.3210 - val_accuracy: 0.6897
# Epoch 26/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0203 - accuracy: 0.9949 - val_loss: 5.8003 - val_accuracy: 0.3589
# Epoch 27/300
# 135/135 [==============================] - 14s 106ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.8748 - val_accuracy: 0.7995
# Epoch 28/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0133 - accuracy: 0.9973 - val_loss: 3.7061 - val_accuracy: 0.3787
# Epoch 29/300
# 135/135 [==============================] - 15s 111ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 2.9482 - val_accuracy: 0.5064
# Epoch 30/300
# 135/135 [==============================] - 14s 105ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 9.4135 - val_accuracy: 0.3161
# Epoch 31/300
# 135/135 [==============================] - 15s 113ms/step - loss: 0.0177 - accuracy: 0.9950 - val_loss: 5.9676 - val_accuracy: 0.3474
# Epoch 32/300
# 135/135 [==============================] - 14s 104ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 7.4305 - val_accuracy: 0.3908
# Epoch 33/300
# 135/135 [==============================] - 18s 136ms/step - loss: 0.0348 - accuracy: 0.9891 - val_loss: 5.7439 - val_accuracy: 0.4681
# Epoch 34/300
# 135/135 [==============================] - 22s 160ms/step - loss: 0.0168 - accuracy: 0.9944 - val_loss: 6.3841 - val_accuracy: 0.3225
# Epoch 35/300
# 135/135 [==============================] - 14s 105ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 3.2127 - val_accuracy: 0.3946
# Epoch 36/300
# 135/135 [==============================] - 14s 107ms/step - loss: 0.0138 - accuracy: 0.9947 - val_loss: 10.4103 - val_accuracy: 0.2395
# Epoch 37/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 6.2116 - val_accuracy: 0.3455
# Epoch 38/300
# 135/135 [==============================] - 14s 105ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 8.6946 - val_accuracy: 0.3442
# Epoch 39/300
# 135/135 [==============================] - 15s 112ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 3.7839 - val_accuracy: 0.4508
# Epoch 40/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 2.3708 - val_accuracy: 0.4860
# Epoch 41/300
# 135/135 [==============================] - 15s 109ms/step - loss: 0.0130 - accuracy: 0.9940 - val_loss: 2.9310 - val_accuracy: 0.4189
# Epoch 42/300
# 135/135 [==============================] - 15s 108ms/step - loss: 0.0095 - accuracy: 0.9962 - val_loss: 7.6666 - val_accuracy: 0.2880
# Epoch 43/300
# 135/135 [==============================] - 23s 169ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 4.7430 - val_accuracy: 0.2867
# Epoch 44/300
# 135/135 [==============================] - 17s 124ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 11.6864 - val_accuracy: 0.1916
# Epoch 45/300
# 135/135 [==============================] - 14s 105ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 4.0997 - val_accuracy: 0.4374
# Epoch 46/300
# 135/135 [==============================] - 15s 110ms/step - loss: 0.0205 - accuracy: 0.9921 - val_loss: 4.7438 - val_accuracy: 0.4610
# Epoch 47/300
# 135/135 [==============================] - 15s 107ms/step - loss: 0.0267 - accuracy: 0.9924 - val_loss: 3.8329 - val_accuracy: 0.5089
# Accuracy: 0.1149
# Precision: 0.1047
# Recall: 0.1176
# F1: 0.0722

# %%
# Print the validation accuracy of each model on their evaluation set
for i in range(n_splits):
    print("Accuracy of ", i+1, " NN: ", scores[i]['accuracy'])
    
    directory = "EfficientNet" + str(i)
    parent_dir = "/kaggle/working/EfficientNet"
    path = os.path.join(parent_dir, directory)
    np.savez_compressed(path, scores=scores[i])
# Out:
# Accuracy of  1  NN:  0.1132884262094305
# Accuracy of  2  NN:  0.12718204488778054
# Accuracy of  3  NN:  0.11132315521628498
# Accuracy of  4  NN:  0.11577608142493638
# Accuracy of  5  NN:  0.14140773620798985
# Accuracy of  6  NN:  0.130625
# Accuracy of  7  NN:  0.12795905310300704
# Accuracy of  8  NN:  0.11962025316455696
# Accuracy of  9  NN:  0.10236724248240563
# Accuracy of  10  NN:  0.11494252873563218

# %%
# Create the zip file
import shutil
shutil.make_archive("Efficient_net_bagging", 'zip', "/kaggle/working/EfficientNet")
# Out:
# '/kaggle/working/Efficient_net_bagging.zip'
